# %% [markdown]
# <a href="https://colab.research.google.com/github/StatsAI/streamlit_image_search/blob/main/E_commerce_reverse_image_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ecommerce: reverse image search
#
# All e-commerce platforms need a search mechanism. The built-in methods usually rely on some variation of full-text search which finds the relevant documents based on the presence of the words used in a query. In some cases, it might be enough, but there are ways to improve that mechanism and increase sales. If your customer can easily find a product they need, they are more likely to buy it.
#
# Semantic search is one of the possibilities. It relies not only on keywords but considers the meaning and intention of the query. However, reverse image search might be a way to go if you want to enable non-textual search capabilities. Your customers may struggle to express themselves, so why don't you ease that and start accepting images as your search queries?
#
# # Amazon product dataset 2020
#
# We will use the [Amazon product dataset 2020](https://www.kaggle.com/datasets/promptcloud/amazon-product-dataset-2020/) and see how to enable visual queries for it. The following lines will download it from the cloud and create a directory structure so you can reproduce the results independently.

# %%
# !mkdir data
# !mkdir data/images
# !mkdir queries
# !wget -nc --directory-prefix=data/ "https://storage.googleapis.com/qdrant-examples/amazon-product-dataset-2020.zip"
# !wget -nc --directory-prefix=queries/ "https://storage.googleapis.com/qdrant-examples/ecommerce-reverse-image-search-queries.zip"
# !unzip -u -d queries queries/ecommerce-reverse-image-search-queries.zip
# Out:
# --2023-07-20 17:15:20--  https://storage.googleapis.com/qdrant-examples/amazon-product-dataset-2020.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.99.128, 142.250.107.128, 74.125.20.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.99.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5627576 (5.4M) [application/zip]
# Saving to: ‘data/amazon-product-dataset-2020.zip’
#
# amazon-product-data 100%[===================>]   5.37M  4.85MB/s    in 1.1s
#
# 2023-07-20 17:15:21 (4.85 MB/s) - ‘data/amazon-product-dataset-2020.zip’ saved [5627576/5627576]
#
# --2023-07-20 17:15:21--  https://storage.googleapis.com/qdrant-examples/ecommerce-reverse-image-search-queries.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.99.128, 142.250.107.128, 74.125.20.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.99.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 120358 (118K) [application/zip]
# Saving to: ‘queries/ecommerce-reverse-image-search-queries.zip’
#
# ecommerce-reverse-i 100%[===================>] 117.54K   357KB/s    in 0.3s
#
# 2023-07-20 17:15:22 (357 KB/s) - ‘queries/ecommerce-reverse-image-search-queries.zip’ saved [120358/120358]
#
# Archive:  queries/ecommerce-reverse-image-search-queries.zip
#   inflating: queries/cable.jpg
#   inflating: queries/cleaning.jpg
#   inflating: queries/skating.jpg
#   inflating: queries/spoon.jpg

# %%
# !pip install jupyter pandas sentence_transformers "qdrant_client~=1.3.0" pyarrow
# Out:
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting qdrant_client~=1.3.0
#   Downloading qdrant_client-1.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (9.0.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter) (6.4.8)
# Collecting qtconsole (from jupyter)
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter) (7.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence_transformers)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence_transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant_client~=1.3.0) (1.56.0)
# Collecting grpcio-tools>=1.41.0 (from qdrant_client~=1.3.0)
#   Downloading grpcio_tools-1.56.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 21.0 MB/s eta 0:00:00
# Collecting httpx[http2]>=0.14.0 (from qdrant_client~=1.3.0)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 5.1 MB/s eta 0:00:00
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant_client~=1.3.0)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pydantic<2.0,>=1.8 in /usr/local/lib/python3.10/dist-packages (from qdrant_client~=1.3.0) (1.10.11)
# Collecting typing-extensions<4.6.0,>=4.0.0 (from qdrant_client~=1.3.0)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant_client~=1.3.0) (1.26.16)
# Collecting protobuf<5.0dev,>=4.21.6 (from grpcio-tools>=1.41.0->qdrant_client~=1.3.0)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 4.6 MB/s eta 0:00:00
# Collecting grpcio>=1.41.0 (from qdrant_client~=1.3.0)
#   Downloading grpcio-1.56.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant_client~=1.3.0) (67.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant_client~=1.3.0) (2023.5.7)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx[http2]>=0.14.0->qdrant_client~=1.3.0)
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant_client~=1.3.0) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.14.0->qdrant_client~=1.3.0) (1.3.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.14.0->qdrant_client~=1.3.0)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 49.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence_transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.9 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (6.3.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter) (3.6.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter) (3.0.8)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter) (2.14.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (5.3.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (5.9.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter) (0.17.1)
# Collecting qtpy>=2.0.1 (from qtconsole->jupyter)
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant_client~=1.3.0)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant_client~=1.3.0)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx[http2]>=0.14.0->qdrant_client~=1.3.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx[http2]>=0.14.0->qdrant_client~=1.3.0) (3.7.1)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->jupyter)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter) (3.8.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter) (4.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx[http2]>=0.14.0->qdrant_client~=1.3.0) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=539fc2e2da02a5c296794067d98109fe630172dad9fef05806549d76233997dd
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: tokenizers, sentencepiece, safetensors, typing-extensions, qtpy, protobuf, portalocker, jedi, hyperframe, hpack, h11, grpcio, huggingface-hub, httpcore, h2, grpcio-tools, transformers, httpx, qtconsole, qdrant_client, jupyter, sentence_transformers
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.56.0
#     Uninstalling grpcio-1.56.0:
#       Successfully uninstalled grpcio-1.56.0
# Successfully installed grpcio-1.56.2 grpcio-tools-1.56.2 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-0.17.3 httpx-0.24.1 huggingface-hub-0.16.4 hyperframe-6.0.1 jedi-0.18.2 jupyter-1.0.0 portalocker-2.7.0 protobuf-4.23.4 qdrant_client-1.3.1 qtconsole-5.4.3 qtpy-2.3.1 safetensors-0.3.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.31.0 typing-extensions-4.5.0

# %% [markdown]
# The dataset is provided as a CSV file and contains multiple attributes of the products, including URLs of the product images. That gives us a real case to work on. Let's check the dataset structure and prepare it for further processing.
#
# **For the testing purposes, we can use only a small subset of the dataset. It's enough to show the concept, but you can easily scale it to the whole dataset. The variable below is a fraction of the dataset that will be used for the rest of the notebook. Feel free to change it to `1.0` if you want to use the whole dataset.**

# %%
DATASET_FRACTION = 0.1

# %% [markdown]
# Now, we can load the dataset and see what it contains.

# %%
import pandas as pd
import zipfile

with zipfile.ZipFile("./data/amazon-product-dataset-2020.zip", "r") as z:
    with z.open("home/sdf/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv") as f:
        dataset_df = pd.read_csv(f).sample(frac=DATASET_FRACTION)

dataset_df.sample(n=5).T
# Out:
#                                                                     8663  \
# Uniq Id                                 d3c1fbb870b9bb5954b408e01f63d737
# Product Name           Crocodile Creek 4130-1 Two-Sided Monkey Jungle...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                          Toys & Games | Puzzles | Floor Puzzles
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $14.99
# Quantity                                                             NaN
# Model Number                                                      4130-1
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:6.5x0.1x7inches|ItemWeight:3...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                              11.2 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants               https://www.amazon.com/Crocodile-Creek-4130-1-...
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Crocodile-Creek-4130-1-...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     7885  \
# Uniq Id                                 5bfa18c6357db5622f98ca001c11abc0
# Product Name           Great Eastern Entertainment Moon Phase Kitty M...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                                                             NaN
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                      $4.18
# Quantity                                                             NaN
# Model Number                                                        3905
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:2.5x2.5x1inches|ItemWeight:0...
# Technical Details      High quality, fully licensed keychain which is...
# Shipping Weight                                               0.8 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Great-Eastern-Entertain...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     4712  \
# Uniq Id                                 b291113e627b36c8a93e07e46f336c69
# Product Name                                     Toomies Push & Go Plane
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                             Toys & Games | Learning & Education
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                      $5.99
# Quantity                                                             NaN
# Model Number                                                      E72241
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:2.6x1.9x3.3inches|ItemWeight...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                              11.2 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Toomies-E72241-Push-Go-...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     1809  \
# Uniq Id                                 218de61f0e0a3e6d044ac1c9f4124615
# Product Name            PlaidHat pH1708 Crystal Clans: Gem Clan, Various
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                Toys & Games | Games & Accessories | Board Games
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                      $9.95
# Quantity                                                             NaN
# Model Number                                                      PH1708
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:5x3.5x0.9inches|ItemWeight:1...
# Technical Details      show up to 2 reviews by default Seek the power...
# Shipping Weight                                              1.44 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/PlaidHat-PH1708-Crystal...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     3603
# Uniq Id                                 d688c4d30f7f543278453d950b65c67a
# Product Name           titan Flower Princess Multi-Sport Protective P...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Sports & Outdoors | Outdoor Recreation | Cycli...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $18.92
# Quantity                                                             NaN
# Model Number                                                        9271
# About Product          Make sure this fits by entering your model num...
# Product Specification  Product Dimensions:         11 x 8 x 2 inches ...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                                 4 ounces
# Product Dimensions                                     11 x 8 x 2 inches
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Titan-Flower-Princess-M...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN

# %%
dataset_df.shape
# Out:
# (1000, 28)

# %%
dataset_df.iloc[0]["Image"]
# Out:
# 'https://images-na.ssl-images-amazon.com/images/I/41yDi0qWTRL.jpg|https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel.jpg'

# %% [markdown]
# It turns out a single product may have several images. They are stored in a pipe-separated string.

# %%
dataset_df.iloc[0]["Image"].split("|")
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/41yDi0qWTRL.jpg',
#  'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel.jpg']

# %% [markdown]
# The last entry is common for multiple products, so we can simply remove it.

# %%
dataset_df["Image"] = dataset_df["Image"].map(lambda x: x.split("|")[:-1])

# %%
dataset_df.iloc[0]["Image"]
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/41yDi0qWTRL.jpg']

# %%
dataset_df = dataset_df.explode("Image").dropna(subset=["Image"])
dataset_df.sample(n=5).T
# Out:
#                                                                     4743  \
# Uniq Id                                 c70ff96dfda28e1f39ab96ecd849ed5c
# Product Name           Optimus Prime Truck with Robot on Chassis from...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                Toys & Games | Play Vehicles | Die-Cast Vehicles
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $24.99
# Quantity                                                             NaN
# Model Number                                                       30446
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:2x7x2.5inches|ItemWeight:1.1...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                              1.19 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Optimus-Transformers-Ho...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     9809  \
# Uniq Id                                 ef62d21e9c5bc96fb19ac060679c3bc9
# Product Name                                Aurora 16" Frog-Lette Fuffle
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Stuffed Animals & Plush Toys | ...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $17.89
# Quantity                                                             NaN
# Model Number                                                       16910
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:4x7x16inches|ItemWeight:6.4o...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                               7.2 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Aurora-World-Inc-Frog-L...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     1739  \
# Uniq Id                                 10e471ca0d7e9809ed9b1414370b6988
# Product Name           DC Comics: Batman (with Bonus Part) Ikemen Statue
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Collectible Toys | Statues, Bob...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $79.97
# Quantity                                                             NaN
# Model Number                                                       DC035
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:4x4x9inches|ItemWeight:1poun...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                                 1 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/DC-Comics-Batman-Ikemen...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     119   \
# Uniq Id                                 c0fd11e864d351e88e9df728bbaa486d
# Product Name                      Nations The Dice Game Unrest Expansion
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                              Toys & Games | Games & Accessories
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $36.91
# Quantity                                                             NaN
# Model Number                                                      7070SG
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:7.5x1x10.8inches|ItemWeight:...
# Technical Details      show up to 2 reviews by default Beware! unrest...
# Shipping Weight                                              1.01 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Nations-Dice-Game-Unres...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
#
#                                                                     2490
# Uniq Id                                 391201805b59ce86ba6dd9994dbbb413
# Product Name           Disney 2-in-1 Battery-Powered Frozen Train wit...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Toy Figures & Playsets | Playse...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $99.99
# Quantity                                                             NaN
# Model Number                                                      060376
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:22.9x10.5x22.8inches|ItemWei...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                             19.75 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Disney-Battery-Powered-...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN

# %% [markdown]
# ## Downloading the images
#
# We want to create the embeddings out of the images, but we need to have them downloaded in the first place.

# %%
dataset_df = dataset_df.sample(frac = 0.05)
dataset_df.shape
# Out:
# (169, 28)

# %%
from typing import Optional

import urllib
import os

def download_file(url: str) -> Optional[str]:
    basename = os.path.basename(url)
    target_path = f"./data/images/{basename}"
    if not os.path.exists(target_path):
        try:
            urllib.request.urlretrieve(url, target_path)
        except urllib.error.HTTPError:
            return None
    return target_path

# %%
import numpy as np

# Our download_file function returns None in case of any HTTP issues.
# We can use that property to filter out the problematic images.
dataset_df["LocalImage"] = dataset_df["Image"].map(download_file).replace({None: np.nan})
dataset_df = dataset_df.dropna(subset=["LocalImage"])
dataset_df.sample(n=5).T
# Out:
#                                                                     6148  \
# Uniq Id                                 b691ff9af9c48c4d3890cda193caaebc
# Product Name           Barbie BMR1959 Fully Poseable Fashion Doll wit...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                      Toys & Games | Dolls & Accessories | Dolls
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $19.99
# Quantity                                                             NaN
# Model Number                                                       GHT91
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:3x6x13inches|ItemWeight:14.1...
# Technical Details      Style:Shorts, Romper & Sweatshirt show up to 2...
# Shipping Weight                                              14.1 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants               https://www.amazon.com/Barbie-BMR-Doll-1959/dp...
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Barbie-BMR-Doll-1959/dp...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/614JovVfV8L.jpg
#
#                                                                     1274  \
# Uniq Id                                 ff2d9b91f16ccd82704617dd4b833eba
# Product Name           LeapFrog Number Lovin' Oven (Frustration Free ...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Kids' Electronics | Electronic ...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $19.29
# Quantity                                                             NaN
# Model Number                                                   80-19347E
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:1.7x8.6x6.5inches|ItemWeight...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                               2.6 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants               https://www.amazon.com/LeapFrog-Number-Lovin-F...
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/LeapFrog-Number-Lovin-F...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/41QEnyS6VaL.jpg
#
#                                                                     2069  \
# Uniq Id                                 95869e007e113c281b757ef88808ffe8
# Product Name                         T.O.T.S. Nursery Stroller Packaging
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Dress Up & Pretend Play | Prete...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $39.97
# Quantity                                                             NaN
# Model Number                                                       49161
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:11x18.2x14.8inches|ItemWeigh...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                              8.55 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/OTS-49161-T-O-T-S-Strol...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/41PPGiiansL.jpg
#
#                                                                     6491  \
# Uniq Id                                 0d45672b2e485502aef4b2908473f23b
# Product Name                         Craft-tastic Needle Felt Pillow Kit
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Arts & Crafts | Craft Kits | Fe...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                      $4.39
# Quantity                                                             NaN
# Model Number                                                      CT1522
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:10x3x10inches|ItemWeight:1po...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                                 1 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Craft-tastic-Needle-Fel...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/51AYVmgQhSL.jpg
#
#                                                                     9842
# Uniq Id                                 71c48d179f670967e121ca4096b189a2
# Product Name           MightySkins Skin Compatible With DJI Spark Dro...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Hobbies | Remote & App Controll...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $49.97
# Quantity                                                             NaN
# Model Number                                        DJSPCMB-Cherry Grain
# About Product          SET THE TREND: Show off your unique style with...
# Product Specification  ProductDimensions:8x0.1x10inches|ItemWeight:0....
# Technical Details      show up to 2 reviews by default Do You Want Yo...
# Shipping Weight                                              0.96 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/MightySkins-Skin-Spark-...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/51IFCeiJQEL.jpg

# %% [markdown]
# ## Creating the embeddings
#
# There are various options for creating the embeddings out of our images. But do not even think about training your neural encoder from scratch! Plenty of pre-trained models are available, and some may already give you some decent results in your domain. And if not, you can use them as a base for the fine-tuning that might be done way faster than the full training.
#
# ### Available options
#
# Using the pretrained models is easy if you choose a library that exposes them with a convenient interface. Some of the possibilities are:
#
# - [torchvision](https://pytorch.org/vision/stable/index.html) - part of PyTorch
# - [embetter](https://koaning.github.io/embetter/) - if you prefer using pandas-like API, that's a great choice
# - [Sentence-Transformers](https://www.sbert.net/examples/applications/image-search/README.html) - one of the standard libraries for NLP exposes OpenAI CLIP model as well
#
# ### Choosing the right model
#
# If you run an e-commerce business, you probably already have a standard full-text search mechanism. Reverse image search is one option to enrich the user experience, but if you also want to experiment with [hybrid search](https://qdrant.tech/articles/hybrid-search/), you should keep that in mind from the beginning. If that's your scenario, it's better to consider multimodality from day one. Such a model can encode texts and images in the same vector space.
#
# For that reason, we are going to use the OpenAI CLIP model, so in the future, we can extend our search mechanism with a semantic search using the same component.

# %%
from sentence_transformers import SentenceTransformer
from PIL import Image

model = SentenceTransformer("clip-ViT-B-32")
# Out:
# Downloading (…)d52eb/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…
#        -3.54155600e-01,  1.47101343e-01,  2.36023903e-01, -3.59713376e-01,
#         3.41270566e-01,  3.06977451e-01,  1.58559263e-01,  7.54409879e-02,
#         1.21323153e-01,  2.49889269e-02, -5.13825893e-01, -2.12855831e-01,
#        -5.39214969e-01, -4.23939317e-01, -1.15222968e-01,  4.07243818e-01,
#         1.04319310e+00, -5.88039994e-01, -4.19527918e-01,  9.75933671e-02,
#         6.44237280e-01, -3.70810449e-01, -1.32362098e-02,  4.50780690e-01,
#         5.15836418e-01,  1.92571990e-02,  7.93525055e-02,  2.76021391e-01,
#        -1.71784580e-01,  1.14316568e-01, -3.86699513e-02,  2.83320725e-01,
#        -1.88192949e-02,  5.92858791e-01,  4.96791184e-01,  5.10058939e-01,
#         2.70200908e-01,  4.56001788e-01, -1.61838531e-01,  1.18291162e-01,
#         2.00704440e-01, -4.77141440e-02,  1.21616885e-01,  1.81566179e-03,
#         3.19471329e-01,  3.38652998e-01,  1.91678405e-01, -2.39977747e-01,
#         4.02281344e-01, -3.64701092e-01, -3.41702104e-02,  1.03083551e-02,
#         4.29884940e-02,  3.22198659e-01,  6.44166917e-02,  1.88629121e-01,
#         1.10444337e-01, -9.11362842e-02,  2.66583323e-01, -6.89959973e-02,
#         2.79854000e-01, -2.36230746e-01, -1.28612190e-01, -6.27506524e-02,
#         2.40984440e-01, -4.28417861e-01,  1.08379044e-01, -2.77369291e-01,
#         3.63564968e-01,  6.12678587e-01, -3.24596882e-01,  1.08265668e-01,
#         8.03418458e-03, -4.09418792e-01,  3.93164098e-01, -1.49788201e-01,
#         1.85860395e-01, -3.94769907e-01, -5.62200546e-01, -2.35460982e-01,
#        -4.11288291e-02, -1.73623174e-01,  4.00884181e-01, -4.53562886e-02,
#        -3.97453666e-01,  5.44175208e-01,  1.84748799e-01,  4.85477924e-01,
#        -6.52983487e-01, -3.07637036e-01,  2.94592738e-01,  5.51942110e-01,
#        -3.54565918e-01,  1.52855098e-01,  1.16283059e-01, -1.58075854e-01],
#       dtype=float32)

# %% [markdown]
# That's what a single embedding look like. But we need to calculate them for each image in our dataset.

# %%
from typing import List

def calculate_embedding(image_path: str) -> Optional[List[float]]:
    try:
        image = Image.open(image_path)
        return model.encode(image).tolist()
    except:
        return None

# %%
# Again, our helper function returns None in case of any error, such as
# unsupported image format. We need to remove those entries.
dataset_df["Embedding"] = dataset_df["LocalImage"].map(calculate_embedding)
dataset_df["Embedding"] = dataset_df["Embedding"].replace({None: np.nan})
dataset_df = dataset_df.dropna(subset=["Embedding"])
dataset_df.sample(n=5).T
# Out:
#                                                                     8546  \
# Uniq Id                                 bbf8b118ebbb6bf0a625df28fd528b67
# Product Name           SunWorks Construction Paper, White, 9" x 12", ...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Arts, Crafts & Sewing | Crafting | Paper & Pap...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                      $2.09
# Quantity                                                             NaN
# Model Number                                                        9203
# About Product          Make sure this fits by entering your model num...
# Product Specification  ASIN:B000EFKAYW|ShippingWeight:11.2ounces(View...
# Technical Details      Color:White show up to 2 reviews by default Su...
# Shipping Weight                                              11.2 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants               https://www.amazon.com/SunWorks-Construction-P...
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/SunWorks-Construction-P...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/51ZNV7WgsUL.jpg
# Embedding              [-0.2236686646938324, 0.013996720314025879, 0....
#
#                                                                     9842  \
# Uniq Id                                 71c48d179f670967e121ca4096b189a2
# Product Name           MightySkins Skin Compatible With DJI Spark Dro...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category               Toys & Games | Hobbies | Remote & App Controll...
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $49.97
# Quantity                                                             NaN
# Model Number                                        DJSPCMB-Cherry Grain
# About Product          SET THE TREND: Show off your unique style with...
# Product Specification  ProductDimensions:8x0.1x10inches|ItemWeight:0....
# Technical Details      show up to 2 reviews by default Do You Want Yo...
# Shipping Weight                                              0.96 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/MightySkins-Skin-Spark-...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/51IFCeiJQEL.jpg
# Embedding              [0.42260897159576416, -0.0818222314119339, 0.0...
#
#                                                                     2932  \
# Uniq Id                                 4a96c75e3ad9e9413f2efe3de38148b4
# Product Name           Breyer 2050 Traditional English Riding Set - H...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                                                             NaN
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $27.49
# Quantity                                                             NaN
# Model Number                                                  B00HV97QOQ
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:27.9x23.6x5.1inches|ItemWeig...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                                 4 ounces
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Breyer-2050-Traditional...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/41kB0oHckDL.jpg
# Embedding              [-0.44876325130462646, 0.14651966094970703, 0....
#
#                                                                     5580  \
# Uniq Id                                 086a1672f2cf1e7bac274fbec7be36e9
# Product Name           Buffalo Games - Charles Wysocki - Proud Lil' A...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                         Toys & Games | Puzzles | Jigsaw Puzzles
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $12.99
# Quantity                                                             NaN
# Model Number                                                       11470
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:2.1x7.9x7.9inches|ItemWeight...
# Technical Details      Go to your orders and start the return Select ...
# Shipping Weight                                              1.25 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Buffalo-Games-Charles-W...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/51tLCGEZy0L.jpg
# Embedding              [0.13095617294311523, 0.3152643144130707, 0.15...
#
#                                                                     3470
# Uniq Id                                 9057dab02cd2f53dfdfb54688237f663
# Product Name           Plus-Plus BIG - Preschool Construction Buildin...
# Brand Name                                                           NaN
# Asin                                                                 NaN
# Category                    Toys & Games | Building Toys | Building Sets
# Upc Ean Code                                                         NaN
# List Price                                                           NaN
# Selling Price                                                     $29.99
# Quantity                                                             NaN
# Model Number                                                       03230
# About Product          Make sure this fits by entering your model num...
# Product Specification  ProductDimensions:15.7x11.8x5.1inches|ItemWeig...
# Technical Details      show up to 2 reviews by default Plus-Plus is a...
# Shipping Weight                                               8.4 pounds
# Product Dimensions                                                   NaN
# Image                  https://images-na.ssl-images-amazon.com/images...
# Variants                                                             NaN
# Sku                                                                  NaN
# Product Url            https://www.amazon.com/Plus-Plus-BIG-Preschool...
# Stock                                                                NaN
# Product Details                                                      NaN
# Dimensions                                                           NaN
# Color                                                                NaN
# Ingredients                                                          NaN
# Direction To Use                                                     NaN
# Is Amazon Seller                                                       Y
# Size Quantity Variant                                                NaN
# Product Description                                                  NaN
# LocalImage                                 ./data/images/41pq1h-puTL.jpg
# Embedding              [0.32750824093818665, 0.10765199363231659, -0....

# %%
dataset_df.to_parquet("./data/amazon-with-embeddings.parquet")

# %% [markdown]
# ## Indexing embeddings in Qdrant
#
# Reverse image search compares the embeddings of the image used as a query and the embeddings of the indexed pictures. That can be theoretically done in a naive way by comparing the query to every single item from our store, but that won't scale if we even go beyond a few hundred. That's what the vector search engines are designed for. Qdrant acts as a fast retrieval layer that performs an efficient search for the closest vectors in the space.
#
# There are various ways to start using Qdrant, and even though the local mode in Python SDK is possible, it should be running as a service in production. The easiest way is to use a Docker container, which we'll do.

# %%
# !docker run -d -p "6333:6333" -p "6334:6334" --name "reverse_image_search" qdrant/qdrant:v1.3.0
# Out:
# /bin/bash: line 1: docker: command not found

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models as rest

try:
    client = QdrantClient("localhost")
    collections = client.get_collections()
except Exception:
    # Docker is unavailable in Google Colab so we switch to local
    # mode available in Python SDK
    client = QdrantClient(":memory:")
    collections = client.get_collections()

collections
# Out:
# CollectionsResponse(collections=[])

# %%
client.recreate_collection(
    collection_name="amazon",
    vectors_config=rest.VectorParams(
        size=512,
        distance=rest.Distance.COSINE,
    )
)
# Out:
# True

# %% [markdown]
# It's a good practice to use batching while inserting the vectors into the collection. Python SDK has a utility method that performs it automatically. For the purposes of our demo, we're going to store vectors with the product id, name, and description as a payload.

# %%
payloads = dataset_df[["Uniq Id", "Product Name", "About Product", "Image", "LocalImage"]] \
    .fillna("Unknown") \
    .rename(columns={"Uniq Id": "ID",
                     "Product Name": "Name",
                     "About Product": "Description",
                     "LocalImage": "Path"}) \
    .to_dict("records")
payloads[0]
# Out:
# {'ID': '196f4917315159c6e17fd014ac296d03',
#  'Name': 'Pure Fun 36-inch Preschool Jumper Kids Trampoline with Handrail, Ages 3 to 7',
#  'Description': 'Make sure this fits by entering your model number. | Spring system is covered with mesh and cushioning to create a safe, worry-free bouncing environment for your children to play and develop their coordination, balance, leg muscles, and stamina | Ergonomic inclined safety bar for increased security and stability; Soft, cushioned handle for firmer, more comfortable gripping | Bouncing system is ASTM, TUV/GS and CE certified for safety; Easy and quick assembly, no additional tools necessary for assembly | Bright, attractive pattern encourages shape, color and ABC recognition; Trampoline dimensions are 36 L x 36 W x 35 H inches including handrail | Frame is sturdy and durable and is capable of sustaining bouncing up to a weight capacity of 75 lbs.; Recommended for ages 3 to 7',
#  'Image': 'https://images-na.ssl-images-amazon.com/images/I/41n0j1gKDGL.jpg',
#  'Path': './data/images/41n0j1gKDGL.jpg'}

# %%
import uuid

client.upload_collection(
    collection_name="amazon",
    vectors=list(map(list, dataset_df["Embedding"].tolist())),
    payload=payloads,
    ids=[uuid.uuid4().hex for _ in payloads],
)

# %%
client.count("amazon")
# Out:
# CountResult(count=168)

# %% [markdown]
# ## Running the reverse image search
#
# As soon as we have the data indexed in Qdrant, it may already start acting as our reverse image search mechanism. Our queries no longer can be just textual, but we can freely use images to find similar items. For that, we surely need a query, and that will rarely be an image from the dataset. Let's find some different examples - for example from [Unsplash](https://unsplash.com), which is a source of freely usable images.

# %%
from io import BytesIO

import base64

def pillow_image_to_base64(image: Image) -> str:
    """
    Convert a Pillow image to a base64 encoded string that can be used as an image
    source in HTML.
    :param image:
    :return:
    """
    buffered = BytesIO()
    image.save(buffered, format="JPEG")
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return f"data:image/jpeg;base64,{img_str}"

# %%
from IPython.display import display, HTML

import glob

query_image_paths = list(glob.glob("./queries/*.jpg"))
images_html = "".join(
    f"<td><img src='{pillow_image_to_base64(Image.open(path))}' width=150></td>"
    for path in query_image_paths
)
display(HTML(f"<table><tr>{images_html}</tr></table>"))
# Out:
# <table><tr><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='data:image/jpeg;base64,...' width=150></td></tr></table>

# %%
for query_image_path in query_image_paths:
    query_image = Image.open(query_image_path)
    query_embedding = model.encode(query_image)

    results = client.search(
        collection_name="amazon",
        query_vector=query_embedding,
        with_payload=True,
        limit=5,
    )

    output_images = [
        pillow_image_to_base64(Image.open(query_image_path)),
    ]
    for result in results:
        output_images.append(result.payload["Image"])

    images_html = "".join(
        f"<td><img src='{path}' width=150></td>"
        for path in output_images
    )
    display(HTML(f"<table><tr>{images_html}</tr></table>"))
# Out:
# <table><tr><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/51ZuQbbIEjL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/31G7FM0IQUL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/4148Qlag10L.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/61zogasXugL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41XB2JTIqBL.jpg' width=150></td></tr></table>
# <table><tr><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41giuP9f%2B4L.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/51IFCeiJQEL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41-QKM2ZZ%2BL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41d1bM72QqL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/314PC-6NAgL.jpg' width=150></td></tr></table>
# <table><tr><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41iIVrK67hL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/310HkwjOQhL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41-O1ndCpVL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41v9UjccIsL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/41XMg7VwKZL.jpg' width=150></td></tr></table>
# <table><tr><td><img src='data:image/jpeg;base64,...' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/317eVMBx%2BaL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/61H87C6taTL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/314PC-6NAgL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/51CH1bf2ZiL.jpg' width=150></td><td><img src='https://images-na.ssl-images-amazon.com/images/I/218exBcrHUL.jpg' width=150></td></tr></table>

# %% [markdown]
# We've implemented a reverse image search mechanism for e-commerce within a single notebook. We can kill the running Docker container for now, so nothing is left dangling in our environment.

# %%
# !docker kill reverse_image_search
# !docker rm reverse_image_search
# Out:
# /bin/bash: line 1: docker: command not found
# /bin/bash: line 1: docker: command not found

# %% [markdown]
# ## Futher steps
#
# The notebook shows the general pipeline of encoding the inventory and using Qdrant to perform the reverse image search. There are, however, some challenges you may encounter while trying to implement it in the real world:
#
# 1. Pretrained models are great to start with but may struggle for some specific kinds of inventory if not trained on similar examples. You can always fine-tune them with small amounts of data to avoid a full training cycle.
# 2. Models should not be hosted within Jupyter notebooks, but there are some ways to serve them efficiently. We're going to describe the possibilities in a separate tutorial.
# 3. If you don't want to worry about maintaining another system in your stack, please consider using [Qdrant Cloud](https://cloud.qdrant.io/), our managed solution. Our tier is free forever and available to everyone - no credit card is required.
